# %%
#ml
## Importing CSV
import matplotlib.pyplot as plt
import pandas as pd 
df = pd.read_csv('cancer.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
## Getting Info about Dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# count       569.000      569.000       569.000         569.000    569.000
# mean   30371831.432       14.127        19.290          91.969    654.889
# std   125020585.612        3.524         4.301          24.299    351.914
# min        8670.000        6.981         9.710          43.790    143.500
# 25%      869218.000       11.700        16.170          75.170    420.300
# 50%      906024.000       13.370        18.840          86.240    551.100
# 75%     8813129.000       15.780        21.800         104.100    782.700
# max   911320502.000       28.110        39.280         188.500   2501.000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count          569.000           569.000         569.000              569.000
# mean             0.096             0.104           0.089                0.049
# std              0.014             0.053           0.080                0.039
# min              0.053             0.019           0.000                0.000
# 25%              0.086             0.065           0.030                0.020
# 50%              0.096             0.093           0.062                0.034
# 75%              0.105             0.130           0.131                0.074
# max              0.163             0.345           0.427                0.201
#
#        symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# count        569.000  ...        569.000          569.000     569.000
# mean           0.181  ...         25.677          107.261     880.583
# std            0.027  ...          6.146           33.603     569.357
# min            0.106  ...         12.020           50.410     185.200
# 25%            0.162  ...         21.080           84.110     515.300
# 50%            0.179  ...         25.410           97.660     686.500
# 75%            0.196  ...         29.720          125.400    1084.000
# max            0.304  ...         49.540          251.200    4254.000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count           569.000            569.000          569.000
# mean              0.132              0.254            0.272
# std               0.023              0.157            0.209
# min               0.071              0.027            0.000
# 25%               0.117              0.147            0.115
# 50%               0.131              0.212            0.227
# 75%               0.146              0.339            0.383
# max               0.223              1.058            1.252
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count               569.000         569.000                  569.000
# mean                  0.115           0.290                    0.084
# std                   0.066           0.062                    0.018
# min                   0.000           0.157                    0.055
# 25%                   0.065           0.250                    0.071
# 50%                   0.100           0.282                    0.080
# 75%                   0.161           0.318                    0.092
# max                   0.291           0.664                    0.207
#
#        Unnamed: 32
# count        0.000
# mean           nan
# std            nan
# min            nan
# 25%            nan
# 50%            nan
# 75%            nan
# max            nan
#
# [8 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 33)

# %%
## Finding Relationships 
df.corr()
# Out:
#                             id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000        0.075         0.100           0.073
# radius_mean              0.075        1.000         0.324           0.998
# texture_mean             0.100        0.324         1.000           0.330
# perimeter_mean           0.073        0.998         0.330           1.000
# area_mean                0.097        0.987         0.321           0.987
# smoothness_mean         -0.013        0.171        -0.023           0.207
# compactness_mean         0.000        0.506         0.237           0.557
# concavity_mean           0.050        0.677         0.302           0.716
# concave points_mean      0.044        0.823         0.293           0.851
# symmetry_mean           -0.022        0.148         0.071           0.183
# fractal_dimension_mean  -0.053       -0.312        -0.076          -0.261
# radius_se                0.143        0.679         0.276           0.692
# texture_se              -0.008       -0.097         0.386          -0.087
# perimeter_se             0.137        0.674         0.282           0.693
# area_se                  0.178        0.736         0.260           0.745
# smoothness_se            0.097       -0.223         0.007          -0.203
# compactness_se           0.034        0.206         0.192           0.251
# concavity_se             0.055        0.194         0.143           0.228
# concave points_se        0.079        0.376         0.164           0.407
# symmetry_se             -0.017       -0.104         0.009          -0.082
# fractal_dimension_se     0.026       -0.043         0.054          -0.006
# radius_worst             0.082        0.970         0.353           0.969
# texture_worst            0.065        0.297         0.912           0.303
# perimeter_worst          0.080        0.965         0.358           0.970
# area_worst               0.107        0.941         0.344           0.942
# smoothness_worst         0.010        0.120         0.078           0.151
# compactness_worst       -0.003        0.413         0.278           0.456
# concavity_worst          0.023        0.527         0.301           0.564
# concave points_worst     0.035        0.744         0.295           0.771
# symmetry_worst          -0.044        0.164         0.105           0.189
# fractal_dimension_worst -0.030        0.007         0.119           0.051
# Unnamed: 32                nan          nan           nan             nan
#
#                          area_mean  smoothness_mean  compactness_mean  \
# id                           0.097           -0.013             0.000
# radius_mean                  0.987            0.171             0.506
# texture_mean                 0.321           -0.023             0.237
# perimeter_mean               0.987            0.207             0.557
# area_mean                    1.000            0.177             0.499
# smoothness_mean              0.177            1.000             0.659
# compactness_mean             0.499            0.659             1.000
# concavity_mean               0.686            0.522             0.883
# concave points_mean          0.823            0.554             0.831
# symmetry_mean                0.151            0.558             0.603
# fractal_dimension_mean      -0.283            0.585             0.565
# radius_se                    0.733            0.301             0.497
# texture_se                  -0.066            0.068             0.046
# perimeter_se                 0.727            0.296             0.549
# area_se                      0.800            0.247             0.456
# smoothness_se               -0.167            0.332             0.135
# compactness_se               0.213            0.319             0.739
# concavity_se                 0.208            0.248             0.571
# concave points_se            0.372            0.381             0.642
# symmetry_se                 -0.072            0.201             0.230
# fractal_dimension_se        -0.020            0.284             0.507
# radius_worst                 0.963            0.213             0.535
# texture_worst                0.287            0.036             0.248
# perimeter_worst              0.959            0.239             0.590
# area_worst                   0.959            0.207             0.510
# smoothness_worst             0.124            0.805             0.566
# compactness_worst            0.390            0.472             0.866
# concavity_worst              0.513            0.435             0.816
# concave points_worst         0.722            0.503             0.816
# symmetry_worst               0.144            0.394             0.510
# fractal_dimension_worst      0.004            0.499             0.687
# Unnamed: 32                    nan              nan               nan
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# id                                0.050                0.044         -0.022
# radius_mean                       0.677                0.823          0.148
# texture_mean                      0.302                0.293          0.071
# perimeter_mean                    0.716                0.851          0.183
# area_mean                         0.686                0.823          0.151
# smoothness_mean                   0.522                0.554          0.558
# compactness_mean                  0.883                0.831          0.603
# concavity_mean                    1.000                0.921          0.501
# concave points_mean               0.921                1.000          0.462
# symmetry_mean                     0.501                0.462          1.000
# fractal_dimension_mean            0.337                0.167          0.480
# radius_se                         0.632                0.698          0.303
# texture_se                        0.076                0.021          0.128
# perimeter_se                      0.660                0.711          0.314
# area_se                           0.617                0.690          0.224
# smoothness_se                     0.099                0.028          0.187
# compactness_se                    0.670                0.490          0.422
# concavity_se                      0.691                0.439          0.343
# concave points_se                 0.683                0.616          0.393
# symmetry_se                       0.178                0.095          0.449
# fractal_dimension_se              0.449                0.258          0.332
# radius_worst                      0.688                0.830          0.186
# texture_worst                     0.300                0.293          0.091
# perimeter_worst                   0.730                0.856          0.219
# area_worst                        0.676                0.810          0.177
# smoothness_worst                  0.449                0.453          0.427
# compactness_worst                 0.755                0.667          0.473
# concavity_worst                   0.884                0.752          0.434
# concave points_worst              0.861                0.910          0.430
# symmetry_worst                    0.409                0.376          0.700
# fractal_dimension_worst           0.515                0.369          0.438
# Unnamed: 32                         nan                  nan            nan
#
#                          ...  texture_worst  perimeter_worst  area_worst  \
# id                       ...          0.065            0.080       0.107
# radius_mean              ...          0.297            0.965       0.941
# texture_mean             ...          0.912            0.358       0.344
# perimeter_mean           ...          0.303            0.970       0.942
# area_mean                ...          0.287            0.959       0.959
# smoothness_mean          ...          0.036            0.239       0.207
# compactness_mean         ...          0.248            0.590       0.510
# concavity_mean           ...          0.300            0.730       0.676
# concave points_mean      ...          0.293            0.856       0.810
# symmetry_mean            ...          0.091            0.219       0.177
# fractal_dimension_mean   ...         -0.051           -0.205      -0.232
# radius_se                ...          0.195            0.720       0.752
# texture_se               ...          0.409           -0.102      -0.083
# perimeter_se             ...          0.200            0.721       0.731
# area_se                  ...          0.196            0.761       0.811
# smoothness_se            ...         -0.075           -0.217      -0.182
# compactness_se           ...          0.143            0.261       0.199
# concavity_se             ...          0.100            0.227       0.188
# concave points_se        ...          0.087            0.395       0.342
# symmetry_se              ...         -0.077           -0.104      -0.110
# fractal_dimension_se     ...         -0.003           -0.001      -0.023
# radius_worst             ...          0.360            0.994       0.984
# texture_worst            ...          1.000            0.365       0.346
# perimeter_worst          ...          0.365            1.000       0.978
# area_worst               ...          0.346            0.978       1.000
# smoothness_worst         ...          0.225            0.237       0.209
# compactness_worst        ...          0.361            0.529       0.438
# concavity_worst          ...          0.368            0.618       0.543
# concave points_worst     ...          0.360            0.816       0.747
# symmetry_worst           ...          0.233            0.269       0.209
# fractal_dimension_worst  ...          0.219            0.139       0.080
# Unnamed: 32              ...            nan              nan         nan
#
#                          smoothness_worst  compactness_worst  concavity_worst  \
# id                                  0.010             -0.003            0.023
# radius_mean                         0.120              0.413            0.527
# texture_mean                        0.078              0.278            0.301
# perimeter_mean                      0.151              0.456            0.564
# area_mean                           0.124              0.390            0.513
# smoothness_mean                     0.805              0.472            0.435
# compactness_mean                    0.566              0.866            0.816
# concavity_mean                      0.449              0.755            0.884
# concave points_mean                 0.453              0.667            0.752
# symmetry_mean                       0.427              0.473            0.434
# fractal_dimension_mean              0.505              0.459            0.346
# radius_se                           0.142              0.287            0.381
# texture_se                         -0.074             -0.092           -0.069
# perimeter_se                        0.130              0.342            0.419
# area_se                             0.125              0.283            0.385
# smoothness_se                       0.314             -0.056           -0.058
# compactness_se                      0.227              0.679            0.639
# concavity_se                        0.168              0.485            0.663
# concave points_se                   0.215              0.453            0.550
# symmetry_se                        -0.013              0.060            0.037
# fractal_dimension_se                0.171              0.390            0.380
# radius_worst                        0.217              0.476            0.574
# texture_worst                       0.225              0.361            0.368
# perimeter_worst                     0.237              0.529            0.618
# area_worst                          0.209              0.438            0.543
# smoothness_worst                    1.000              0.568            0.519
# compactness_worst                   0.568              1.000            0.892
# concavity_worst                     0.519              0.892            1.000
# concave points_worst                0.548              0.801            0.855
# symmetry_worst                      0.494              0.614            0.533
# fractal_dimension_worst             0.618              0.810            0.687
# Unnamed: 32                           nan                nan              nan
#
#                          concave points_worst  symmetry_worst  \
# id                                      0.035          -0.044
# radius_mean                             0.744           0.164
# texture_mean                            0.295           0.105
# perimeter_mean                          0.771           0.189
# area_mean                               0.722           0.144
# smoothness_mean                         0.503           0.394
# compactness_mean                        0.816           0.510
# concavity_mean                          0.861           0.409
# concave points_mean                     0.910           0.376
# symmetry_mean                           0.430           0.700
# fractal_dimension_mean                  0.175           0.334
# radius_se                               0.531           0.095
# texture_se                             -0.120          -0.128
# perimeter_se                            0.555           0.110
# area_se                                 0.538           0.074
# smoothness_se                          -0.102          -0.107
# compactness_se                          0.483           0.278
# concavity_se                            0.440           0.198
# concave points_se                       0.602           0.143
# symmetry_se                            -0.030           0.389
# fractal_dimension_se                    0.215           0.111
# radius_worst                            0.787           0.244
# texture_worst                           0.360           0.233
# perimeter_worst                         0.816           0.269
# area_worst                              0.747           0.209
# smoothness_worst                        0.548           0.494
# compactness_worst                       0.801           0.614
# concavity_worst                         0.855           0.533
# concave points_worst                    1.000           0.503
# symmetry_worst                          0.503           1.000
# fractal_dimension_worst                 0.511           0.538
# Unnamed: 32                               nan             nan
#
#                          fractal_dimension_worst  Unnamed: 32
# id                                        -0.030          nan
# radius_mean                                0.007          nan
# texture_mean                               0.119          nan
# perimeter_mean                             0.051          nan
# area_mean                                  0.004          nan
# smoothness_mean                            0.499          nan
# compactness_mean                           0.687          nan
# concavity_mean                             0.515          nan
# concave points_mean                        0.369          nan
# symmetry_mean                              0.438          nan
# fractal_dimension_mean                     0.767          nan
# radius_se                                  0.050          nan
# texture_se                                -0.046          nan
# perimeter_se                               0.085          nan
# area_se                                    0.018          nan
# smoothness_se                              0.101          nan
# compactness_se                             0.591          nan
# concavity_se                               0.439          nan
# concave points_se                          0.311          nan
# symmetry_se                                0.078          nan
# fractal_dimension_se                       0.591          nan
# radius_worst                               0.093          nan
# texture_worst                              0.219          nan
# perimeter_worst                            0.139          nan
# area_worst                                 0.080          nan
# smoothness_worst                           0.618          nan
# compactness_worst                          0.810          nan
# concavity_worst                            0.687          nan
# concave points_worst                       0.511          nan
# symmetry_worst                             0.538          nan
# fractal_dimension_worst                    1.000          nan
# Unnamed: 32                                  nan          nan
#
# [32 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
# df.drop(['Unnamed: 32'], axis=1, inplace = True)
df.drop(['id'], axis=1, inplace = True)
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
feature_cols = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean','smoothness_mean', 'compactness_mean', 'concavity_mean','concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']

# %%
x = df[feature_cols]
y = df.diagnosis.values

# %%
## Using Min Max Normalization 
import numpy as np
x = (x - np.min(x)) / (np.max(x) - np.min(x))
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          0.521         0.023           0.546      0.364            0.594
# 1          0.643         0.273           0.616      0.502            0.290
# 2          0.601         0.390           0.596      0.449            0.514
# 3          0.210         0.361           0.234      0.103            0.811
# 4          0.630         0.157           0.631      0.489            0.430
# ..           ...           ...             ...        ...              ...
# 564        0.690         0.429           0.679      0.566            0.527
# 565        0.622         0.627           0.604      0.474            0.408
# 566        0.455         0.621           0.446      0.303            0.288
# 567        0.645         0.664           0.666      0.476            0.588
# 568        0.037         0.502           0.029      0.016            0.000
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0               0.792           0.703                0.731          0.686
# 1               0.182           0.204                0.349          0.380
# 2               0.431           0.463                0.636          0.510
# 3               0.811           0.566                0.523          0.776
# 4               0.348           0.464                0.518          0.378
# ..                ...             ...                  ...            ...
# 564             0.296           0.571                0.690          0.336
# 565             0.258           0.337                0.487          0.349
# 566             0.254           0.217                0.264          0.268
# 567             0.790           0.823                0.755          0.675
# 568             0.074           0.000                0.000          0.266
#
#      fractal_dimension_mean
# 0                     0.606
# 1                     0.141
# 2                     0.211
# 3                     1.000
# 4                     0.187
# ..                      ...
# 564                   0.132
# 565                   0.113
# 566                   0.137
# 567                   0.425
# 568                   0.187
#
# [569 rows x 10 columns]

# %%
M = df[df.diagnosis == "M"]

B = df[df.diagnosis == "B"]

plt.title("Malignant vs Benign Tumor")
plt.xlabel("Radius Mean")
plt.ylabel("Texture Mean")
plt.scatter(M.radius_mean, M.texture_mean, color = "red", label = "Malignant", alpha = 0.3)
plt.scatter(B.radius_mean, B.texture_mean, color = "lime", label = "Benign", alpha = 0.3)
plt.legend()
plt.show()

# %%
df.diagnosis.value_counts().plot(kind='pie',shadow=True,colors=('darkgreen','orange'),autopct='%.2f',figsize=(8,6))
plt.title('Diagnosis')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import plot_tree

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

print("Training split input- ", x_train.shape)
print("Testing split input- ", x_test.shape)
# Out:
# Training split input-  (455, 10)
# Testing split input-  (114, 10)

# %%
from sklearn.tree import DecisionTreeClassifier 
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
print("Classification report - \n", classification_report(y_test,y_pred))
# Out:
# Classification report -
#                precision    recall  f1-score   support
#
#            B       0.95      0.93      0.94        67
#            M       0.90      0.94      0.92        47
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.93      0.93       114
# weighted avg       0.93      0.93      0.93       114

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[62,  5],
#        [ 3, 44]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,5))

sns.heatmap(data=cm,linewidths=1.0, annot=True,square = True,  cmap = 'Blues')

plt.ylabel('Actual label')
plt.xlabel('Predicted label')

all_sample_title = 'Accuracy Score: {0}'.format(dt.score(x_test, y_test))
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.9298245614035088')

# %%
# Visualising the graph without the use of graphviz

plt.figure(figsize = (50,50))
dec_tree = plot_tree(decision_tree=dt, feature_names = df.columns, class_names =["Malignant", "Benign"] , filled = True , precision = 4, rounded = True)

# %%
from sklearn.model_selection import cross_val_score
from sklearn import model_selection as ms 
from numpy import mean 

cv = ms.KFold( n_splits = 5, random_state = 20, shuffle=True)
scores = cross_val_score(dt, x , y, scoring="accuracy", cv = cv)
print(scores)
# Out:
# [0.92982456 0.92982456 0.94736842 0.88596491 0.9380531 ]

# %%
mean(scores)
# Out:
# 0.9262071106970966

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['diagnosis'])
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
